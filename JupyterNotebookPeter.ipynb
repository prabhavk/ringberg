# %% [markdown]
# ### This is Julia!

# %%
using PyPlot

# %%
scatter(rand(30), rand(30))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x7fcbd403a130>
